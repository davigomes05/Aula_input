# %% [markdown]
# <a href="https://colab.research.google.com/github/davigomes05/Aula_input/blob/main/Aula_14_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite o seu nome: ")
print("O seu nome é: ", nome)
# Out:
# Digite o seu nome: davi
# O seu nome é:  davi

# %%
###### atividade 01
valor1 = int(input("Digite o primeiro valor: "))
valor2 = int(input("Digite o segundo valor: "))
resultado = valor1 + valor2
print(resultado)
# Out:
# Digite o primeiro valor: 55
# Digite o segundo valor: 55
# 110

# %%
# atividade 02
valor1 = int(input("Digite o primeiro valor: "))
valor2 = int(input("Digite o segundo valor: "))
soma = valor1 + valor2
print(soma)
# Out:
# Digite o primeiro valor: 10
# Digite o segundo valor: 2
# 12

# %%
soma = valor1 + valor2
subtracao = valor1 - valor2
div = valor1 / valor2
mult = valor1 * valor2
print(soma, subtracao, div, mult)
# Out:
# 12 8 5.0 20

# %%
usuario = input("Digite o seu nome: ")
print("Olá",usuario,"Seja Bem Vindo")
# Out:
# Digite o seu nome: Maria Eduarda
# Olá Maria Eduarda Seja Bem Vindo
